# %% [markdown]
# # SI 618 Project Description
#
# ## Mental Health Indicator relationships with Alcohol Consumption and
#
# ### names here

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
mental_health = pd.read_csv('data/U.S._Chronic_Disease_Indicators__Mental_Health_20240217.csv')

# %%
# Number of records by year
mental_health.groupby('YearStart').size().plot(kind='bar', title='Number of Mental Health Records by Year')
for i, v in enumerate(mental_health.groupby('YearStart').size()):
    plt.text(i, v + 10, str(v), ha='center', fontsize=8)
plt.show()

# %%
reproductive_health = pd.read_csv('data/U.S._Chronic_Disease_Indicators__Reproductive_Health_20240219.csv')

# %%
reproductive_health.Stratification1.unique()
# Out:
# array(['Overall', 'Hispanic', 'White, non-Hispanic',
#        'Asian or Pacific Islander', 'Multiracial, non-Hispanic',
#        'Other, non-Hispanic', 'Black, non-Hispanic',
#        'American Indian or Alaska Native'], dtype=object)

# %%
mental_health.Stratification1.unique()
# Out:
# array(['Overall', 'Black, non-Hispanic', 'Female', 'Hispanic',
#        'Multiracial, non-Hispanic', 'Other, non-Hispanic', 'Male',
#        'White, non-Hispanic'], dtype=object)

# %%
alcohol.Stratification1.unique()
# Out:
# array(['Female', 'Male', 'Asian, non-Hispanic', 'White, non-Hispanic',
#        'Overall', 'Hispanic', 'Black, non-Hispanic',
#        'Asian or Pacific Islander', 'Multiracial, non-Hispanic',
#        'Other, non-Hispanic', 'American Indian or Alaska Native'],
#       dtype=object)

# %%
mental_health.head(3)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 0       2018     2018           NV       Nevada      BRFSS  Mental Health
# 1       2020     2020           NV       Nevada      BRFSS  Mental Health
# 2       2018     2018           NV       Nevada      BRFSS  Mental Health
#
#                                             Question  Response DataValueUnit  \
# 0  At least 14 recent mentally unhealthy days amo...       NaN             %
# 1  Recent mentally unhealthy days among adults ag...       NaN        Number
# 2  Recent mentally unhealthy days among adults ag...       NaN        Number
#
#       DataValueType  ...  LocationID  TopicID QuestionID DataValueTypeID  \
# 0  Crude Prevalence  ...          32      MTH     MTH2_0         CRDPREV
# 1              Mean  ...          32      MTH     MTH1_0            MEAN
# 2              Mean  ...          32      MTH     MTH1_0            MEAN
#
# ...

# %%
mental_health.shape
# Out:
# (13200, 33)

# %%
mental_health.DataSource.value_counts()
# Out:
# DataSource
# BRFSS    13145
# PRAMS       55
# Name: count, dtype: int64

# %%
mental_health.Question.value_counts()
# Out:
# Question
# Recent mentally unhealthy days among adults aged >= 18 years               9570
# At least 14 recent mentally unhealthy days among women aged 18-44 years    3575
# Postpartum depressive symptoms                                               55
# Name: count, dtype: int64

# %%
mental_health.YearStart.value_counts()
# Out:
# YearStart
# 2018    1195
# 2020    1195
# 2019    1195
# 2017    1195
# 2016    1195
# 2011    1195
# 2012    1195
# 2013    1195
# 2015    1195
# 2021    1195
# 2014    1195
# 2009      55
# Name: count, dtype: int64

# %%
mental_health[mental_health.YearStart != mental_health.YearEnd]
# Out:
#     YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 40       2009     2011           US         United States      PRAMS
# 44       2009     2011           NV                Nevada      PRAMS
# 45       2009     2011           VA              Virginia      PRAMS
# 46       2009     2011           IN               Indiana      PRAMS
# 47       2009     2011           NH         New Hampshire      PRAMS
# 48       2009     2011           MS           Mississippi      PRAMS
# 49       2009     2011           FL               Florida      PRAMS
# 50       2009     2011           LA             Louisiana      PRAMS
# 51       2009     2011           SC        South Carolina      PRAMS
# 52       2009     2011           WA            Washington      PRAMS
# 53       2009     2011           GA               Georgia      PRAMS
# 54       2009     2011           MI              Michigan      PRAMS
# 55       2009     2011           CT           Connecticut      PRAMS
# ...

# %%
alcohol = pd.read_csv('data/U.S._Chronic_Disease_Indicators__Alcohol_20240217.csv')
# Out:
# /var/folders/7k/kt8nfzwd2pvgsvfsrs6vyjsm0000gn/T/ipykernel_18030/4228160081.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   alcohol = pd.read_csv('data/U.S._Chronic_Disease_Indicators__Alcohol_20240217.csv')

# %%
alcohol.shape
# Out:
# (66091, 33)

# %%
alcohol.Question.value_counts()
# Out:
# Question
# Chronic liver disease mortality                                           13497
# Binge drinking frequency among adults aged >= 18 years who binge drink     9570
# Binge drinking intensity among adults aged >= 18 years who binge drink     9570
# Binge drinking prevalence among adults aged >= 18 years                    9570
# Heavy drinking among adults aged >= 18 years                               9570
# Binge drinking prevalence among women aged 18-44 years                     3575
# Heavy drinking among women aged 18-44 years                                3575
# Alcohol use before pregnancy                                               2783
# Alcohol use among youth                                                    1760
# Binge drinking prevalence among youth                                       990
# Per capita alcohol consumption among persons aged >= 14 years               330
# Amount of alcohol excise tax by beverage type (beer)                        324
# ...

# %%
alcohol.YearStart.value_counts()
# Out:
# YearStart
# 2019    6810
# 2017    6706
# 2015    6362
# 2013    6124
# 2020    5985
# 2012    5839
# 2018    5768
# 2014    5718
# 2016    5684
# 2011    5467
# 2021    4346
# 2010    1282
# Name: count, dtype: int64

# %%
len(mental_health['LocationAbbr'].value_counts())
# Out:
# 55

# %%
len(alcohol['LocationAbbr'].value_counts())
# Out:
# 55

# %%
# Count number of common columns
len(set(mental_health.columns).intersection(set(alcohol.columns)))
# Out:
# 33

# %%
# List of common columns
set(mental_health.columns).intersection(set(alcohol.columns))
# Out:
# {'DataSource',
#  'DataValue',
#  'DataValueAlt',
#  'DataValueFootnoteSymbol',
#  'DataValueType',
#  'DataValueTypeID',
#  'DataValueUnit',
#  'DatavalueFootnote',
#  'HighConfidenceLimit',
#  'LocationAbbr',
#  'LocationDesc',
#  'LocationID',
#  'LowConfidenceLimit',
#  'Question',
#  'QuestionID',
#  'Response',
#  'ResponseID',
#  'Stratification1',
#  'Stratification2',
#  'Stratification3',
#  'StratificationCategory1',
#  'StratificationCategory2',
#  'StratificationCategory3',
#  'StratificationCategoryID1',
#  'StratificationCategoryID2',
#  'StratificationCategoryID3',
#  'StratificationID1',
#  'StratificationID2',
#  'StratificationID3',
#  'Topic',
#  'TopicID',
#  'YearEnd',
#  'YearStart'}

# %%
# merge the two datasets on the location abbreviation and year start, preserving all in mental_health, and labeling the repeated columns appropriately
merge_columns = ['YearStart', 'YearEnd', 'LocationDesc', 'LocationAbbr', 'LocationID', 'DataSource', 'StratificationCategoryID1', 'StratificationID1']
mental_health_alcohol = pd.merge(mental_health, alcohol, on=merge_columns, how='inner', suffixes=('_mental_health', '_alcohol'))

# %%
mental_health_alcohol.shape
# Out:
# (126610, 58)

# %%
mental_health_alcohol.head(3)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 0       2018     2018           NV       Nevada      BRFSS
# 1       2018     2018           NV       Nevada      BRFSS
# 2       2018     2018           NV       Nevada      BRFSS
#
#   Topic_mental_health                             Question_mental_health  \
# 0       Mental Health  At least 14 recent mentally unhealthy days amo...
# 1       Mental Health  At least 14 recent mentally unhealthy days amo...
# 2       Mental Health  At least 14 recent mentally unhealthy days amo...
#
#    Response_mental_health DataValueUnit_mental_health  \
# 0                     NaN                           %
# 1                     NaN                           %
# 2                     NaN                           %
#
#   DataValueType_mental_health  ...  StratificationCategory3_alcohol  \
# 0            Crude Prevalence  ...                              NaN
# 1            Crude Prevalence  ...                              NaN
# ...

# %%
len(mental_health.LocationID.value_counts())
# Out:
# 55

# %%
mental_health.StratificationID1.value_counts()
# Out:
# StratificationID1
# OVR     1870
# BLK     1782
# HIS     1782
# MRC     1782
# OTH     1782
# WHT     1782
# GENF    1210
# GENM    1210
# Name: count, dtype: int64
